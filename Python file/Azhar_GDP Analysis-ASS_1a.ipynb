# %%
##Which state has been growing consistantly at fast and which state is struggling? 

#Curiosity exercise: what has been the average growth rate of your home state and how does it compare to the
# national average over this duration 

##Plot the GDP of the state for the year 2015-2016
 #Identify the top 5 and the bottom 5 states based on the total GDP
    
    

import numpy as np 
import pandas as pd 
import os
os.path.isfile('/Users/azharhussain/Desktop/Ass.csv')
df_1a= pd.read_csv('/Users/azharhussain/Desktop/Ass.csv')
df_1a.head(12)
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
#Removing rows i.e GSDP for 2016-2017 and %GSDP for 2016-2017
df_1a.drop([5,10],inplace= True)

#Removing West Bengal and All_India GDP
#df_1a.drop(['West Bengal1','All_India GDP'], axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-8ab78d65f0d5> in <module>
#       1 #Removing rows i.e GSDP for 2016-2017 and %GSDP for 2016-2017
# ----> 2 df_1a.drop([5,10],inplace= True)
#       3
#       4 #Removing West Bengal and All_India GDP
#       5 df_1a.drop(['West Bengal1','All_India GDP'], axis=1, inplace= True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...

# %%
df_1a.head(10)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
#df_1a.drop(['West Bengal1', 'All_India GDP'], axis=1, inplace= True)
df_1a.head(10)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
#Finding mean of %GSDP
df_percentageGSDP=df_1a.loc[6:10,:].mean()
sort_df_percentageGSDP=df_percentageGSDP.sort_values()
print(sort_df_percentageGSDP)
# Out:
# Goa                           2.020000
# Meghalaya                     7.667500
# Sikkim                       10.492500
# Odisha                       10.712500
# Jammu & Kashmir              11.002500
# Punjab                       11.346667
# All_India GDP                11.867500
# Assam                        11.877500
# Manipur                      11.890000
# Rajasthan                    11.940000
# Puducherry                   12.097500
# Maharashtra                  12.103333
# Uttar Pradesh                12.367500
# Uttarakhand                  12.382500
# Telangana                    12.497500
# Jharkhand                    12.567500
# Delhi                        12.572500
# Andhra Pradesh               12.632500
# Tamil Nadu                   12.712500
# Kerala                       12.752500
# Chandigarh                   12.755000
# Gujarat                      12.767500
# Himachal Pradesh             12.816667
# Andaman & Nicobar Islands    12.900000
# ...

# %%
import matplotlib.pyplot as plt

# %%
sort_df_percentageGSDP.plot.bar()

# %%
##Which state has been growing consistantly at fast and which state is struggling? 

#Curiosity exercise: what has been the average growth rate of your home state and how does it compare to the
# national average over this duration 

##Plot the GDP of the state for the year 2015-2016
 #Identify the top 5 and the bottom 5 states based on the total GDP

# %%
#Selecting 2015-2016 data from the dataframe df_1a
df_1a_20015=df_1a.iloc[4]
print(df_1a_20015)
# Out:
# Items  Description           GSDP - CURRENT PRICES (` in Crore)
# Duration                                                2015-16
# Andhra Pradesh                                           609934
# Arunachal Pradesh                                         18784
# Assam                                                    224234
# Bihar                                                    413503
# Chhattisgarh                                             260776
# Goa                                                       45002
# Gujarat                                                  994316
# Haryana                                                  485184
# Himachal Pradesh                                            NaN
# Jammu & Kashmir                                          118387
# Jharkhand                                                241955
# Karnataka                                           1.02707e+06
# Kerala                                                   588337
# ...

# %%
##Plot the GDP of the state for the year 2015-2016

df_1a_20015_sort=df_1a_20015.sort_values()

#print(df_1a_20015_sort)
 
    
df_1a_20015_sort.plot.bar()
#df_1a_20015.set_index ("Items  Description", inplace = False)

# %%
#Identify the top 5 and the bottom 5 states based on the total GDP
